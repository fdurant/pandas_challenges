# %% [markdown]
# # Challenge 1

# %% [markdown]
# Plot domestic total gross over time

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
moviesDF=pd.read_csv('2013_movies.csv', sep=',', header=0, index_col=6, parse_dates=True)
moviesDF.head()
# Out:
#                                        Title     Budget  DomesticTotalGross  \
# ReleaseDate
# 2013-11-22   The Hunger Games: Catching Fire  130000000           424668047
# 2013-05-03                        Iron Man 3  200000000           409013994
# 2013-11-22                            Frozen  150000000           400738009
# 2013-07-03                   Despicable Me 2   76000000           368061265
# 2013-06-14                      Man of Steel  225000000           291045518
#
#                               Director Rating  Runtime
# ReleaseDate
# 2013-11-22            Francis Lawrence  PG-13      146
# 2013-05-03                 Shane Black  PG-13      129
# 2013-11-22      Chris BuckJennifer Lee     PG      108
# 2013-07-03   Pierre CoffinChris Renaud     PG       98
# 2013-06-14                 Zack Snyder  PG-13      143

# %%
print moviesDF.columns
print moviesDF.index
# Out:
# Index([u'Title', u'Budget', u'DomesticTotalGross', u'Director', u'Rating', u'Runtime'], dtype='object')
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2013-11-22, ..., 2013-12-18]
# Length: 100, Freq: None, Timezone: None

# %%
# %matplotlib inline

moviesDF['DomesticTotalGross'].plot(kind='area')
plt.title('Domestic Total Gross over time')

plt.show()

# %% [markdown]
# # Challenge 2

# %% [markdown]
# plot runtime vs domestic total gross

# %%
#moviesDF.plot(x='Runtime', y='DomesticTotalGross', style='o')
plt.scatter(moviesDF['Runtime'], moviesDF['DomesticTotalGross'])
plt.xlabel('Runtime (days)')
plt.ylabel('DomesticTotalGross (USD)')
plt.title('Runtime vs. domestic total gross')
plt.show()

# %% [markdown]
# # Challenge 3

# %% [markdown]
# group your data by Rating and find the average runtime and domestic total gross at each level of Rating

# %%
moviesDFGroupedByRating = moviesDF.groupby('Rating')
print moviesDFGroupedByRating['Runtime'].mean()
# Out:
# Rating
# G         107.000000
# PG         99.933333
# PG-13     117.510638
# R         110.729730
# Name: Runtime, dtype: float64

# %%
print moviesDFGroupedByRating['DomesticTotalGross'].mean()
# Out:
# Rating
# G         268492764
# PG        131135716
# PG-13     111449769
# R          69892429
# Name: DomesticTotalGross, dtype: int64

# %% [markdown]
# # Challenge 4

# %% [markdown]
# make one figure with (N=the number of MPAA ratings there are) subplots, and in each plot the release date vs the domestic total gross

# %%
moviesDF.loc[moviesDF['Rating'] == 'G'].head()
# Out:
#                            Title  Budget  DomesticTotalGross     Director  \
# ReleaseDate
# 2013-06-21   Monsters University     NaN           268492764  Dan Scanlon
#
#             Rating  Runtime
# ReleaseDate
# 2013-06-21       G      107

# %%
moviesDF.loc[moviesDF['Rating'] == 'PG'].head()
# Out:
#                                            Title     Budget  \
# ReleaseDate
# 2013-11-22                                Frozen  150000000
# 2013-07-03                       Despicable Me 2   76000000
# 2013-03-08             Oz The Great and Powerful  215000000
# 2013-03-22                            The Croods  135000000
# 2013-09-27   Cloudy with a Chance of Meatballs 2   78000000
#
#              DomesticTotalGross                    Director Rating  Runtime
# ReleaseDate
# 2013-11-22            400738009      Chris BuckJennifer Lee     PG      108
# 2013-07-03            368061265   Pierre CoffinChris Renaud     PG       98
# 2013-03-08            234911825                   Sam Raimi     PG      127
# 2013-03-22            187168425  Kirk De MiccoChris Sanders     PG       98
# 2013-09-27            119793567                         NaN     PG       95

# %%
moviesDF.loc[moviesDF['Rating'] == 'PG-13'].head()
# Out:
#                                            Title     Budget  \
# ReleaseDate
# 2013-11-22       The Hunger Games: Catching Fire  130000000
# 2013-05-03                            Iron Man 3  200000000
# 2013-06-14                          Man of Steel  225000000
# 2013-10-04                               Gravity  100000000
# 2013-12-13   The Hobbit: The Desolation of Smaug        NaN
#
#              DomesticTotalGross          Director Rating  Runtime
# ReleaseDate
# 2013-11-22            424668047  Francis Lawrence  PG-13      146
# 2013-05-03            409013994       Shane Black  PG-13      129
# 2013-06-14            291045518       Zack Snyder  PG-13      143
# 2013-10-04            274092705    Alfonso Cuaron  PG-13       91
# 2013-12-13            258366855     Peter Jackson  PG-13      161

# %%
moviesDF.loc[moviesDF['Rating'] == 'R'].head()
# Out:
#                          Title    Budget  DomesticTotalGross  \
# ReleaseDate
# 2013-06-28            The Heat  43000000           159582188
# 2013-08-07   We're the Millers  37000000           150394119
# 2013-12-13     American Hustle  40000000           150117807
# 2013-07-19       The Conjuring  20000000           137400141
# 2013-02-08      Identity Thief  35000000           134506920
#
#                             Director Rating  Runtime
# ReleaseDate
# 2013-06-28                 Paul Feig      R      117
# 2013-08-07   Rawson Marshall Thurber      R      110
# 2013-12-13          David O. Russell      R      138
# 2013-07-19                 James Wan      R      112
# 2013-02-08               Seth Gordon      R      111

# %%
plt.figure(1, figsize=(15,10))

moviesDF.loc[moviesDF['Rating'] == 'G']['DomesticTotalGross'].plot(label='G')
moviesDF.loc[moviesDF['Rating'] == 'PG']['DomesticTotalGross'].plot(label='PG')
moviesDF.loc[moviesDF['Rating'] == 'PG-13']['DomesticTotalGross'].plot(label='PG-13')
moviesDF.loc[moviesDF['Rating'] == 'R']['DomesticTotalGross'].plot(label='R')
plt.legend()
plt.ylabel('DomesticTotalGross')
plt.title('Domestic Total Gross over time, per MPAA Rating')
plt.show()

# %% [markdown]
# # Challenge 5

# %% [markdown]
# what director in your dataset has the highest gross per movie?

# %%
moviesDFGroupedByDirector = moviesDF.groupby('Director')
dtgSeriesByDirector = moviesDFGroupedByDirector['DomesticTotalGross'].sum()
dtgSeriesByDirector.sort(axis=0, ascending=False)
dtgSeriesByDirector.head()
# Out:
# Director
# Francis Lawrence             424668047
# Shane Black                  409013994
# Chris BuckJennifer Lee       400738009
# Pierre CoffinChris Renaud    368061265
# Zack Snyder                  291045518
# Name: DomesticTotalGross, dtype: int64

# %% [markdown]
# # Challenge 6

# %% [markdown]
# bin your dataset into years (if applicable) and make a bar graph with error bars of gross each year

# %%
from datetime import datetime, date 
# Doing it by month instead of by year, for the sake of the exercise
moviesDFGroupedByMonth = moviesDF.groupby(lambda x: x.month)
dtgSeriesByMonth = moviesDFGroupedByMonth['DomesticTotalGross'].sum()
dtgStdByMonth = moviesDFGroupedByMonth['DomesticTotalGross'].std()
#dtgSeriesByMonth.values

plt.bar(np.array(dtgSeriesByMonth.index),dtgSeriesByMonth.values,yerr=dtgStdByMonth)
plt.title('Domestic Total Gross in 2013, per month')
plt.xlabel('Month')
plt.ylabel('Domestic Total Gross (USD)')
plt.show()
